# %% [markdown]
# Importing the dependencies

# %%
# !pip install pandas numpy matplotlib
import numpy as np
import pandas as pd
df = pd.DataFrame
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
#first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 17500  28773 -0.430412  1.018080  1.560273 -0.025709 -0.061009 -0.904727
# 17501  28774 -1.184230  1.025272  1.722521 -0.246293  0.689898  1.006001
# 17502  28775  1.067437 -0.828109  0.456921  0.510196 -0.881389  0.149908
# 17503  28776 -6.392357  4.547807 -7.610294  2.051154 -3.701227 -2.361965
# 17504  28777  0.877247 -0.990305  0.565650  0.150685 -0.770408  0.625613
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 17500  0.698988 -0.064000 -0.390847  ... -0.225444 -0.598821 -0.012457
# 17501  0.474374  0.400677 -0.506778  ...  0.221976  0.824696 -0.164754
# 17502 -0.474485 -0.092441 -0.585492  ... -0.193558 -0.188801 -0.302328
# 17503 -2.346386  4.345503 -0.186320  ... -0.079794 -0.754866 -0.147426
# 17504 -0.494277  0.187495  1.210786  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# 17500  0.359689 -0.192403  0.071511  0.263548  0.121474    5.38    0.0
# 17501 -0.589006  0.132438  0.562652  0.053304  0.109783    3.99    0.0
# 17502 -0.435477  0.622916 -0.190089  0.056720  0.054231  158.00    0.0
# 17503  0.063744  0.106242 -0.374011  0.041010 -0.266988   89.99    0.0
# 17504       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
# dataset information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17505 entries, 0 to 17504
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    17505 non-null  int64
#  1   V1      17505 non-null  float64
#  2   V2      17505 non-null  float64
#  3   V3      17505 non-null  float64
#  4   V4      17505 non-null  float64
#  5   V5      17505 non-null  float64
#  6   V6      17505 non-null  float64
#  7   V7      17505 non-null  float64
#  8   V8      17505 non-null  float64
#  9   V9      17505 non-null  float64
#  10  V10     17505 non-null  float64
#  11  V11     17505 non-null  float64
#  12  V12     17505 non-null  float64
#  13  V13     17505 non-null  float64
#  14  V14     17505 non-null  float64
#  15  V15     17505 non-null  float64
#  16  V16     17505 non-null  float64
#  17  V17     17505 non-null  float64
#  18  V18     17505 non-null  float64
#  19  V19     17505 non-null  float64
#  20  V20     17504 non-null  float64
#  21  V21     17504 non-null  float64
#  22  V22     17504 non-null  float64
#  23  V23     17504 non-null  float64
#  24  V24     17504 non-null  float64
#  25  V25     17504 non-null  float64
#  26  V26     17504 non-null  float64
#  27  V27     17504 non-null  float64
#  28  V28     17504 non-null  float64
#  29  Amount  17504 non-null  float64
#  30  Class   17504 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 4.1 MB

# %%
# checking the no. of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# 0.0    17423
# 1.0       81
# Name: Class, dtype: int64

# %% [markdown]
# The dataset is highly unbalanced

# %% [markdown]
# 0 - Normal Transaction
#
# 1 - Fraud Transaction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (17423, 31)
# (81, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    17423.000000
# mean        66.995542
# std        188.199763
# min          0.000000
# 25%          5.490000
# 50%         15.950000
# 75%         56.000000
# max       7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      81.000000
# mean       98.105926
# std       267.464067
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# Compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    13535.804282 -0.210842  0.236097   0.841988  0.268584 -0.109687
# 1.0    16833.074074 -9.315066  6.779465 -13.052870  6.451318 -6.557541
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.114310 -0.107933 -0.008790  0.774634  ...  0.030926 -0.058689
# 1.0   -2.602613 -9.012856  4.730365 -3.087651  ...  0.756424  0.549752
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.152664 -0.035827  0.015201  0.117958  0.036023  0.010593  0.006289
# 1.0   -0.423495 -0.398104 -0.277836  0.355688  0.177616  0.940693  0.090007
#
#           Amount
# Class
# 0.0    66.995542
# 1.0    98.105926
#
# [2 rows x 30 columns]

# %% [markdown]
# Undersampling

# %%
Built a similar dataset containing similar distribution of legit transaction and fraud transaction

# %% [markdown]
# Number of fraud transactions - 81

# %%
legit_sample = legit.sample(n=81)

# %% [markdown]
# Concatenating two Dataframes

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 6985    9125 -1.496341  1.329327 -1.843953  0.467938  1.532789  3.465834
# 12263  21420 -0.595767  0.399339  2.333499 -1.897170 -0.038179 -0.189552
# 10755  18259 -0.702216  0.359377  2.554977 -1.951633 -0.004972  0.313918
# 15697  27124 -0.597244  0.293077  2.408902  0.862389  0.067151  2.479563
# 13675  24241  1.004211  0.005801  1.410018  1.375881 -0.741639  0.297069
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 6985  -0.997015  1.880471  0.360773  ...  0.233545  0.316191  0.038708
# 12263  0.382062 -0.165075  2.690432  ... -0.218669 -0.098078 -0.468518
# 10755  0.214060  0.073132  2.350598  ... -0.106813  0.247219 -0.408211
# 15697 -0.537279  0.888624 -0.256252  ...  0.189837  0.856445  0.033563
# 13675 -0.734505  0.215221  1.477864  ...  0.068933  0.393614  0.014016
#
#             V24       V25       V26       V27       V28  Amount  Class
# 6985   0.966139 -0.904527 -0.435634 -0.495051  0.011360   50.00    0.0
# 12263 -0.515555  0.560503 -0.788711 -0.087551 -0.161669   11.85    0.0
# 10755 -0.359592  0.396124 -0.808918 -0.069850 -0.170067    5.40    0.0
# 15697 -0.947646 -0.668837  0.656566  0.204142  0.103239   28.75    0.0
# 13675  0.152068  0.170970 -0.403956  0.041086  0.029306   45.00    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    81
# 1.0    81
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    12900.419753 -0.399277  0.421587   0.826002  0.229561  0.037209
# 1.0    16833.074074 -9.315066  6.779465 -13.052870  6.451318 -6.557541
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.347430 -0.132860  0.220251  0.794298  ... -0.002568 -0.060063
# 1.0   -2.602613 -9.012856  4.730365 -3.087651  ...  0.756424  0.549752
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.063843 -0.103930 -0.079431  0.083885 -0.016941 -0.026116 -0.030911
# 1.0   -0.423495 -0.398104 -0.277836  0.355688  0.177616  0.940693  0.090007
#
#           Amount
# Class
# 0.0    45.828889
# 1.0    98.105926
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into the Features and Targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']
print(X)
# Out:
#         Time         V1         V2         V3        V4         V5        V6  \
# 6985    9125  -1.496341   1.329327  -1.843953  0.467938   1.532789  3.465834
# 12263  21420  -0.595767   0.399339   2.333499 -1.897170  -0.038179 -0.189552
# 10755  18259  -0.702216   0.359377   2.554977 -1.951633  -0.004972  0.313918
# 15697  27124  -0.597244   0.293077   2.408902  0.862389   0.067151  2.479563
# 13675  24241   1.004211   0.005801   1.410018  1.375881  -0.741639  0.297069
# ...      ...        ...        ...        ...       ...        ...       ...
# 17317  28625 -27.848181  15.598193 -28.923756  6.418442 -20.346228 -4.828202
# 17366  28658 -28.524268  15.876923 -29.468732  6.447591 -20.786000 -4.865613
# 17407  28692 -29.200329  16.155701 -30.013712  6.476731 -21.225810 -4.902997
# 17453  28726 -29.876366  16.434525 -30.558697  6.505862 -21.665654 -4.940356
# 17480  28755 -30.552380  16.713389 -31.103685  6.534984 -22.105532 -4.977692
#
#               V7         V8        V9  ...       V20       V21       V22  \
# 6985   -0.997015   1.880471  0.360773  ... -0.310008  0.233545  0.316191
# 12263   0.382062  -0.165075  2.690432  ... -0.069015 -0.218669 -0.098078
# 10755   0.214060   0.073132  2.350598  ... -0.103787 -0.106813  0.247219
# 15697  -0.537279   0.888624 -0.256252  ...  0.138958  0.189837  0.856445
# 13675  -0.734505   0.215221  1.477864  ... -0.110768  0.068933  0.393614
# ...          ...        ...       ...  ...       ...       ...       ...
# 17317 -19.210896  18.329406 -3.668735  ...  1.697856  1.802149 -2.062934
# 17366 -19.501084  18.748872 -3.642990  ...  1.706889  1.805770 -2.119376
# 17407 -19.791248  19.168327 -3.617242  ...  1.715862  1.809371 -2.175815
# 17453 -20.081391  19.587773 -3.591491  ...  1.724779  1.812954 -2.232252
# 17480 -20.371514  20.007208 -3.565738  ...  1.733644  1.816520 -2.288686
#
#             V23       V24       V25       V26       V27       V28  Amount
# 6985   0.038708  0.966139 -0.904527 -0.435634 -0.495051  0.011360   50.00
# 12263 -0.468518 -0.515555  0.560503 -0.788711 -0.087551 -0.161669   11.85
# 10755 -0.408211 -0.359592  0.396124 -0.808918 -0.069850 -0.170067    5.40
# 15697  0.033563 -0.947646 -0.668837  0.656566  0.204142  0.103239   28.75
# 13675  0.014016  0.152068  0.170970 -0.403956  0.041086  0.029306   45.00
# ...         ...       ...       ...       ...       ...       ...     ...
# 17317 -1.269843  0.165409  1.999499 -0.211059  1.324809  0.388090   99.99
# 17366 -1.317450  0.169846  2.051687 -0.210502  1.301734  0.380246   99.99
# 17407 -1.365104  0.174286  2.103868 -0.209944  1.278681  0.372393   99.99
# 17453 -1.412803  0.178731  2.156042 -0.209385  1.255649  0.364530   99.99
# 17480 -1.460544  0.183179  2.208209 -0.208824  1.232636  0.356660   99.99
#
# [162 rows x 30 columns]

# %%
print(Y)
# Out:
# 6985     0.0
# 12263    0.0
# 10755    0.0
# 15697    0.0
# 13675    0.0
#         ...
# 17317    1.0
# 17366    1.0
# 17407    1.0
# 17453    1.0
# 17480    1.0
# Name: Class, Length: 162, dtype: float64

# %% [markdown]
# Split the data into Training data and Testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (162, 30) (129, 30) (33, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()
# training the Logistic Regression model with training data
model.fit(X_train, Y_train)

# %% [markdown]
# Evaluation (Model)

# %% [markdown]
# Accuracy Score

# %%
#accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

print('Accuracy on training data : ' ,training_data_accuracy)
# Out:
# Accuracy on training data :  0.9922480620155039

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9090909090909091
